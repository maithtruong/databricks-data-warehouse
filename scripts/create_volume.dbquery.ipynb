-- %%
/*
  DDL Script: Create Volumes
  Description:
    Create two new volumes on the core_dev catalog and source schema to attach new data files.
*/

USE CATALOG core_dev;
USE SCHEMA source;
CREATE VOLUME IF NOT EXISTS source_crm;
CREATE VOLUME IF NOT EXISTS source_erp;

-- %%
/*
  DDL Script: Create a new development catalog and bronze, silver and gold schemas.
*/

CREATE CATALOG IF NOT EXISTS core_dev;

USE CATALOG core_dev;
CREATE SCHEMA IF NOT EXISTS core_dev.bronze;
CREATE SCHEMA IF NOT EXISTS core_dev.silver;
CREATE SCHEMA IF NOT EXISTS core_dev.gold;
